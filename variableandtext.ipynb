# %%
a = 2
b = "2"

print("a =",a,"type =",type(a))
print("b =",b,"type =",type(b))
# Out:
# a = 2 type = <class 'int'>
# b = 2 type = <class 'str'>

# %%
print('execution started')
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# print("a + b =",a + b)
print("converting a into string and then + opration ,a + b = ",str(a) + b)
print('execution ended')
# Out:
# execution started
# a + b =  22
# execution ended

# %%
print('execution started')

print("converting b into int and then doing + opration , a + b =",a + int(b))
print('execution ended')
# Out:
# execution started
# a + b = 4
# execution ended
